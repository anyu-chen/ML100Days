# %%
#Q1：大樂透的頭獎，你必須從49個挑選出 6 個號碼，且這六個號碼與頭獎的六個號碼一致，頭獎的機率是屬於哪一種分配？
#Q2：運用範例的 python 程式碼，計算大樂透的中頭獎機率？

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics

n = 6
K = 6
N = 49
r = np.arange(0, min(n + 1,K + 1))
first = stats.hypergeom.pmf(r, N, K, n)
print("Q1/Q2 answer: use Hypergeometric Distribution, possibility = ", first[5])

plt.ylabel('Possibility')
plt.xlabel('Times')
plt.title("First prize possibility")
plt.plot(r, first)
plt.show()
# Out:
# Q1/Q2 answer: use Hypergeometric Distribution, possibility =  1.8449899512407806e-05

# %%
#Q3：你覺得電腦簽注的中獎機率，和人腦簽注相比，哪一個機率高？˙
print("理論上機率是相同的, 但仍要根據當期開出的號碼決定, 因為人腦簽注可能會避開某寫特定數字而造成中獎機率高於或低於電腦簽注")
# Out:
# 理論上機率是相同的, 但仍要根據當期開出的號碼決定, 因為人腦簽注可能會避開某寫特定數字而造成中獎機率高於或低於電腦簽注
